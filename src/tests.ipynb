# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/geoff/anaconda3/envs/irl_env/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
from src.problems import EasyMaze
from src.policy import Policy

Easy_Maze = EasyMaze()

opt_pol_arr = np.zeros(len(Easy_Maze.states))
for x in Easy_Maze.states:
    j, k = np.unravel_index(x, (Easy_Maze.side, Easy_Maze.side))
    if j >= k:
        opt_pol_arr[x] = Easy_Maze.right
    else:
        opt_pol_arr[x] = Easy_Maze.down

opt_pol = Policy(opt_pol_arr)

traj, rews = Easy_Maze.simulate(0, opt_pol, 1)
Easy_Maze.plot_trajectory(traj)
# Out:
# /media/geoff/SHARED/MVA/Projects/IRL_with_Constraints/src/MDP.py:34: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   rand_var = rv_discrete(values=(self.states, self.dynamics[state, action]))

# %%
Easy_Maze.plot_reward()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-954c653aab47> in <module>()
# ----> 1 Easy_Maze.plot_reward()
#
# NameError: name 'Easy_Maze' is not defined
